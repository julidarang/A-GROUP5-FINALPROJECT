# %%
import requests
from bs4 import BeautifulSoup

url = "https://ppp.gov.ph/project-database/"
response = requests.get(url)
page_text = response.text
soup = BeautifulSoup(page_text)
selector = "body > div:nth-child(7) > div.large-9.medium-8.columns.center > div.large-6.columns.map-result > table"
view_content_element = soup.select(selector)[0]
new_selector = "tbody > tr"
table_rows = view_content_element.select(new_selector)

page_data = []
for tr in table_rows:
    cols = tr.find_all('td')
    title_selector = cols[0]
    title = title_selector.text
    region_selector = cols[1]
    region = region_selector.text
    sector_selector = cols[2]
    sector = sector_selector.text
    status_selector = cols[3]
    status = status_selector.text.split(",")[0]
    try:
        award = status_selector.text.split(",")[1]
    except:
        award = None
    agent_selector = cols[4]
    agent = agent_selector.text
    
    page_data.append({"Project Title" : title, "Region" : region, "Sector" : sector, "Status" : status, "Award" : award, "Implementing Agency" : agent})

#page_data[7]["Award"] = page_data[7]["Status"] # status and award was switched since og status was only "Awarded"
#page_data[7]["Status"] = "Unkown"

#for j in table_rows: 
    rows = tr.find("a")
    ref = rows.get("href")
    
    new_resp = requests.get(ref)
    c_text = new_resp.text
    c_soup = BeautifulSoup(c_text)
    b_selector = "body > div:nth-child(7) > div.large-9.medium-8.columns.center > div.su-accordion > div > div > div.su-spoiler-content.su-clearfix"
    view_body = c_soup.select(b_selector)[0]

    c = view_body.find_all("p")
    
    try:
        
        if c[3].text.strip().lower().find("php") == 0 or c[3].text.strip().lower().find("usd") == 0 or c[3].text.strip().lower().find("million") > 0 or c[3].text.strip().lower().find("billion") > 0 or c[3].text.strip().lower().find("milion") > 0 or c[3].text.strip().lower().find("bilion") > 0 or c[3].text.strip().lower().find("-") == 0 or c[3].text.strip().lower().find("tbd") == 0 or c[3].text.strip().lower().find("for") == 0:
            project_cost = c[3].text.strip() 
        elif c[4].text.strip().lower().find("php") == 0 or c[4].text.strip().lower().find("usd") == 0 or c[4].text.strip().lower().find("tbd") == 0 or c[4].text.strip().find("-") == 0 or c[4].text.strip().lower().find("million") > 0 or c[4].text.strip().lower().find("milion") > 0 or c[4].text.strip().lower().find("billion") > 0 or c[4].text.strip().lower().find("bilion") > 0 or c[4].text.strip().lower().find("for") == 0:
            project_cost = c[4].text.strip() 
        elif c[5].text.strip().lower().find("php") == 0 or c[5].text.strip().lower().find("usd") == 0 or c[5].text.strip().lower().find("tbd") == 0 or c[5].text.strip().find("-") == 0 or c[5].text.strip().lower().find("million") > 0 or c[5].text.strip().lower().find("milion") > 0 or c[5].text.strip().lower().find("billion") > 0 or c[5].text.strip().lower().find("bilion") > 0 or c[5].text.strip().lower().find("for") == 0:
            project_cost = c[5].text.strip() 
        elif c[6].text.strip().lower().find("php") == 0 or c[6].text.strip().lower().find("usd") == 0 or c[6].text.strip().lower().find("tbd") == 0 or c[6].text.strip().find("-") == 0 or c[6].text.strip().lower().find("million") > 0 or c[6].text.strip().lower().find("milion") > 0 or c[6].text.strip().lower().find("billion") > 0 or c[6].text.strip().lower().find("bilion") > 0 or c[6].text.strip().lower().find("for") == 0:
            project_cost = c[6].text.strip() 
        elif c[7].text.strip().lower().find("php") == 0 or c[7].text.strip().lower().find("usd") == 0 or c[7].text.strip().lower().find("tbd") == 0 or c[7].text.strip().find("-") == 0 or c[7].text.strip().lower().find("million") > 0 or c[7].text.strip().lower().find("milion") > 0 or c[7].text.strip().lower().find("billion") > 0 or c[7].text.strip().lower().find("bilion") > 0 or c[7].text.strip().lower().find("for") == 0:
            project_cost = c[7].text.strip() 
        elif c[8].text.strip().lower().find("php") == 0 or c[8].text.strip().lower().find("usd") == 0 or c[8].text.strip().lower().find("tbd") == 0 or c[8].text.strip().find("-") == 0 or c[8].text.strip().lower().find("million") > 0 or c[8].text.strip().lower().find("milion") > 0 or c[8].text.strip().lower().find("billion") > 0 or c[8].text.strip().lower().find("bilion") > 0 or c[8].text.strip().lower().find("for") == 0:
            project_cost = c[8].text.strip() 
        elif c[2].text.strip().lower().find("php") == 0 or c[2].text.strip().lower().find("usd") == 0 or c[2].text.strip().lower().find("tbd") == 0 or c[2].text.strip().find("-") == 0 or c[2].text.strip().lower().find("million") > 0 or c[2].text.strip().lower().find("milion") > 0 or c[2].text.strip().lower().find("billion") > 0 or c[2].text.strip().lower().find("bilion") > 0 or c[2].text.strip().lower().find("for") == 0:
            project_cost = c[2].text.strip() 
        elif c[9].text.strip().lower().find("php") == 0 or c[9].text.strip().lower().find("usd") == 0 or c[9].text.strip().lower().find("tbd") == 0 or c[9].text.strip().find("-") == 0 or c[9].text.strip().lower().find("million") > 0 or c[9].text.strip().lower().find("milion") > 0 or c[9].text.strip().lower().find("billion") > 0 or c[9].text.strip().lower().find("bilion") > 0 or c[9].text.strip().lower().find("for") == 0:
            project_cost = c[9].text.strip()
        elif c[10].text.strip().lower().find("php") == 0 or c[10].text.strip().lower().find("usd") == 0 or c[10].text.strip().lower().find("tbd") == 0 or c[10].text.strip().find("-") == 0 or c[10].text.strip().lower().find("million") > 0 or c[10].text.strip().lower().find("milion") > 0 or c[10].text.strip().lower().find("billion") > 0 or c[10].text.strip().lower().find("bilion") > 0 or c[10].text.strip().lower().find("for") == 0:
            project_cost = c[10].text.strip()
        elif c[11].text.strip().lower().find("php") == 0 or c[11].text.strip().lower().find("usd") == 0 or c[11].text.strip().lower().find("tbd") == 0 or c[11].text.strip().find("-") == 0 or c[11].text.strip().lower().find("million") > 0 or c[11].text.strip().lower().find("milion") > 0 or c[11].text.strip().lower().find("billion") > 0 or c[11].text.strip().lower().find("bilion") > 0 or c[11].text.strip().lower().find("for") == 0:
            project_cost = c[11].text.strip()
        
        #print(project_cost)
        
    except:
        project_cost = "Not Indicated" #178/177 -> shudve said not indicated

    #print(page_data, project_cost)
    #print(project_cost)
#for b in range(len(page_data)):
 #   print(project_cost[b])
    page_data.append({"Cost" : project_cost})

#page_data[7]["Award"] = page_data[7]["Status"] # status and award was switched since og status was only "Awarded"
#page_data[7]["Status"] = "Unkown"

page_data
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-36db99cd0fc6> in <module>
#      38     ref = rows.get("href")
#      39
# ---> 40     new_resp = requests.get(ref)
#      41     c_text = new_resp.text
#      42     c_soup = BeautifulSoup(c_text)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ...

# %%
for j in table_rows:
    rows = j.find("a")
    ref = rows.get("href")
    
    new_resp = requests.get(ref)
    c_text = new_resp.text
    c_soup = BeautifulSoup(c_text)
    b_selector = "body > div:nth-child(7) > div.large-9.medium-8.columns.center > div.su-accordion > div > div > div.su-spoiler-content.su-clearfix"
    view_body = c_soup.select(b_selector)[0]

    c = view_body.find_all("p")
    
    try:
        cost = c[3].text.strip()
        cost_two = c[6].text.strip()
        cost_three = c[4].text.strip()
        cost_four = c[5].text.strip()
        cost_five = c[7].text.strip()
        cost_six = c[8].text.strip()
        cost_seven = c[2].text.strip()
        cost_eight = c[9].text.strip()
        cost_nine = c[11].text.strip()

        if cost.lower().find("php") == 0 or cost.lower().find("usd") == 0 or cost.lower().find("tbd") == 0 or cost.find("-") == 0 or cost.lower().find("mil") > 0 or cost.lower().find("bil") > 0 or cost.lower().find("for") == 0:
            project_cost = cost 
        elif cost_two.lower().find("php") == 0 or cost_two.lower().find("usd") == 0 or cost_two.lower().find("tbd") == 0 or cost_two.find("-") == 0 or cost_two.lower().find("mil") > 0 or cost_two.lower().find("bil") > 0 or cost_two.lower().find("for") == 0:
            project_cost = cost_two
        elif cost_three.lower().find("php") == 0 or cost_three.lower().find("usd") == 0 or cost_three.lower().find("tbd") == 0 or cost_three.find("-") == 0 or cost_three.lower().find("mil") > 0 or cost_three.lower().find("bil") > 0 or cost_three.lower().find("for") == 0:
            project_cost = cost_seven
        elif cost_four.lower().find("php") == 0 or cost_four.lower().find("usd") == 0 or cost_four.lower().find("tbd") == 0 or cost_four.find("-") == 0 or cost_four.lower().find("mil") > 0 or cost_four.lower().find("bil") > 0 or cost_four.lower().find("for") == 0:
            project_cost = cost_four
        elif cost_five.lower().find("php") == 0 or cost_five.lower().find("usd") == 0 or cost_five.lower().find("tbd") == 0 or cost_five.find("-") == 0 or cost_five.lower().find("mil") > 0 or cost_five.lower().find("bil") > 0 or cost_five.lower().find("for") == 0:
            project_cost = cost_five
        elif cost_six.lower().find("php") == 0 or cost_six.lower().find("usd") == 0 or cost_six.lower().find("tbd") == 0 or cost_six.find("-") == 0 or cost_six.lower().find("mil") > 0 or cost_six.lower().find("bil") > 0 or cost_six.lower().find("for") == 0:
            project_cost = cost_six
        elif cost_seven.lower().find("php") == 0 or cost_seven.lower().find("usd") == 0 or cost_seven.lower().find("tbd") == 0 or cost_seven.find("-") == 0 or cost_seven.lower().find("mil") > 0 or cost_seven.lower().find("bil") > 0 or cost_seven.lower().find("for") == 0:
            project_cost = cost_seven
        elif cost_eight.lower().find("php") == 0 or cost_eight.lower().find("usd") == 0 or cost_eight.lower().find("tbd") == 0 or cost_eight.find("-") == 0 or cost_eight.lower().find("mil") > 0 or cost_eight.lower().find("bil") > 0 or cost_eight.lower().find("for") == 0:
            project_cost = cost_seven
        else:
            project_cost = cost_nine
        print(project_cost)
        
    except:
        print("Error")
# Out:
# Php 1,604.59 Million
#
#
# TBD
# Error
# Error
# Error
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-161-5558d20f436d> in <module>
#       3     ref = rows.get("href")
#       4
# ----> 5     new_resp = requests.get(ref)
#       6     c_text = new_resp.text
#       7     c_soup = BeautifulSoup(c_text)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ...

# %%
import re

for j in table_rows:
    rows = j.find("a")
    ref = rows.get("href")
    
    new_resp = requests.get(ref)
    c_text = new_resp.text
    c_soup = BeautifulSoup(c_text)
    b_selector = "body > div:nth-child(7) > div.large-9.medium-8.columns.center > div.su-accordion > div > div > div.su-spoiler-content.su-clearfix"
    view_body = c_soup.select(b_selector)[0]

    c = view_body.find_all("p")
    #print(c[2])

# %%
for j in table_rows:
    rows = j.find("a")
    ref = rows.get("href")
    
    new_resp = requests.get(ref)
    c_text = new_resp.text
    c_soup = BeautifulSoup(c_text)
    b_selector = "body > div:nth-child(7) > div.large-9.medium-8.columns.center > div.su-accordion > div > div > div.su-spoiler-content.su-clearfix"
    view_body = c_soup.select(b_selector)[0]

    c = view_body.find_all("p")
    #d = c.p.stripped_strings
    #print(c)

# %%
for j in table_rows:
    rows = j.find("a")
    ref = rows.get("href")
    
    new_resp = requests.get(ref)
    c_text = new_resp.text
    c_soup = BeautifulSoup(c_text)
    b_selector = "body > div:nth-child(7) > div.large-9.medium-8.columns.center > div.su-accordion > div > div > div.su-spoiler-content.su-clearfix"
    view_body = c_soup.select(b_selector)[0]

    c = view_body.find_all("p")
    
    try:
        for i in range(11):
            if c[i].text.strip().lower().find("php") == 0 or c[i].text.strip().lower().find("usd") == 0 or c[i].text.strip().lower().find("tbd") == 0 or c[i].text.strip().find("-") == 0 or c[i].text.strip().lower().find("million") > 0 or c[i].text.strip().lower().find("milion") > 0 or c[i].text.strip().lower().find("billion") > 0 or c[i].text.strip().lower().find("bilion") > 0 or c[i].text.strip().lower().find("for validation") >= 0:
                project_cost = c[i].text.strip()
    except:
        project_cost = "Error", ref
    #print(project_cost)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-159-88ce9e0ab839> in <module>
#       3     ref = rows.get("href")
#       4
# ----> 5     new_resp = requests.get(ref)
#       6     c_text = new_resp.text
#       7     c_soup = BeautifulSoup(c_text)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ...

# %%
y = "9 Million"

y.lower().find("mil")
# Out:
# 2

# %%
for j in table_rows:
    rows = j.find("a")
    ref = rows.get("href")
    
    new_resp = requests.get(ref)
    c_text = new_resp.text
    c_soup = BeautifulSoup(c_text)
    b_selector = "body > div:nth-child(7) > div.large-9.medium-8.columns.center > div.su-accordion > div > div > div.su-spoiler-content.su-clearfix"
    view_body = c_soup.select(b_selector)[0]

    c = view_body.find_all("p")
    
    try:
        cost = c[2].text.strip()
        cost_two = c[3].text.strip()
        cost_three = c[4].text.strip()
        cost_four = c[5].text.strip()
        cost_five = c[6].text.strip()
        cost_six = c[7].text.strip()
        cost_eight = c[8].text.strip()

        if cost.lower().find("php") == 0 or cost.lower().find("usd") == 0 or cost.lower().find("tbd") == 0 or cost.find("-") == 0 or cost.lower().find("million") > 0 or cost.lower().find("milion") > 0 or cost.lower().find("billion") > 0 or cost.lower().find("bilion") > 0 or cost.lower().find("for") == 0:
            project_cost = cost 
        elif cost_two.lower().find("php") == 0 or cost_two.lower().find("usd") == 0 or cost_two.lower().find("tbd") == 0 or cost_two.find("-") == 0 or cost_two.lower().find("million") > 0 or cost_two.lower().find("milion") > 0 or cost_two.lower().find("billion") > 0 or cost_two.lower().find("bilion") > 0 or cost_two.lower().find("for") == 0:
            project_cost = cost_two 
        elif cost_three.lower().find("php") == 0 or cost_three.lower().find("usd") == 0 or cost_three.lower().find("tbd") == 0 or cost_three.find("-") == 0 or cost_three.lower().find("million") > 0 or cost_three.lower().find("milion") > 0 or cost_three.lower().find("billion") > 0 or cost_three.lower().find("bilion") > 0 or cost_three.lower().find("for") == 0:
            project_cost = cost_three 
        elif cost_four.lower().find("php") == 0 or cost_four.lower().find("usd") == 0 or cost_four.lower().find("tbd") == 0 or cost_four.find("-") == 0 or cost_four.lower().find("million") > 0 or cost_four.lower().find("milion") > 0 or cost_four.lower().find("billion") > 0 or cost_four.lower().find("bilion") > 0 or cost_four.lower().find("for") == 0:
            project_cost = cost_four 
        elif cost_five.lower().find("php") == 0 or cost_five.lower().find("usd") == 0 or cost_five.lower().find("tbd") == 0 or cost_five.find("-") == 0 or cost_five.lower().find("million") > 0 or cost_five.lower().find("milion") > 0 or cost_five.lower().find("billion") > 0 or cost_five.lower().find("bilion") > 0 or cost_five.lower().find("for") == 0:
            project_cost = cost_five 
        elif cost_six.lower().find("php") == 0 or cost_six.lower().find("usd") == 0 or cost_six.lower().find("tbd") == 0 or cost_six.find("-") == 0 or cost_six.lower().find("million") > 0 or cost_six.lower().find("milion") > 0 or cost_six.lower().find("billion") > 0 or cost_six.lower().find("bilion") > 0 or cost_six.lower().find("for") == 0:
            project_cost = cost_six 
        elif cost_seven.lower().find("php") == 0 or cost_seven.lower().find("usd") == 0 or cost_seven.lower().find("tbd") == 0 or cost_seven.find("-") == 0 or cost_seven.lower().find("million") > 0 or cost_seven.lower().find("milion") > 0 or cost_seven.lower().find("billion") > 0 or cost_seven.lower().find("bilion") > 0 or cost_seven.lower().find("for") == 0:
            project_cost = cost_seven 
        else:
            project_cost = cost_eight
        print(project_cost)
        
    except:
        print("Error")
# Out:
# Php 1,604.59 Million
# Php 7,604.90 Million
# Php 5,229.90 Million
# TBD
# TBD
# Php 110,817,774.31
# -
# Php 6.128 Billion
# Php 5.5 Billion
# -
# Php 9.138 Billion
# Php 0.0495 Billion
# Php 17.4 Billion
# Error
# Error
# Php 5.2 Billion
# Php 551 Million
# Php 2.180 Billion
# Php 240 Million
# Php 2,140.63
# Php 3,153.69 Million
# Php 1,598.07
# -
# Php 1,124.41 Million
# -
# Php 2,955.97 Million
# Php 2,164.00 Million
# Php 1,457.00 Million
# Php 1,031.17 Million
# Php 1,624.23 Million
# Php 2,661.13 Million
# Php 3,711.22
# Php 2,918.46 Million
# -
# Php 570.26 Million
# Php 2,343.34 Million
# Php 6,143.74 Million
# Php 1,787.14 Million
# Php 3,343 Million
# Php 1,554.74 Million
# Php 1,366.88 Million
# Php 1,902.69 Million
# -
# Php 2.9863 Billion
# Php 642.37 Million
# -
# -
# Php 2.80 Billion
# Php 12.350 Billion
# -
# Php 308.60 Million
# Php 4.00 Billion
# Php 26.020 Billion
# -
# Php 48.54 Million
# Php 35.5 Billion
# Php 757.61 Million
# -
# -
# -
# Php 1.00 Billion
# -
# ...

# %%
u = "https://ppp.gov.ph/ppp_projects/metro-manila-subway-project-mmsp-operations-and-maintenance-om-ppp-project/"

r = requests.get(u)
t = r.text
s = BeautifulSoup(t)
a = "body > div:nth-child(7) > div.large-9.medium-8.columns.center > div.su-accordion > div > div > div.su-spoiler-content.su-clearfix"
v = s.select(a)[0]

x = v.find_all("p")
d = x[3].text.strip()

if d.lower().find("php") == 0 or d.lower().find("usd") == 0 or d.lower().find("million") > 0 or d.lower().find("billion") > 0 or d.lower().find("milion") > 0 or d.lower().find("bilion") > 0 or d.lower().find("-") == 0 or d.lower().find("tbd") == 0 or d.lower().find("for") == 0:
    p = d
print(p)
# Out:
# Php 2.66 Billion

# %%
u = ["https://ppp.gov.ph/ppp_projects/operations-and-maintenance-of-the-north-south-commuter-rail/", "https://ppp.gov.ph/ppp_projects/metro-manila-subway-project-mmsp-operations-and-maintenance-om-ppp-project/", "https://ppp.gov.ph/ppp_projects/puerto-galera-sewerage-and-wastewater-treatment-plant-project/", "https://ppp.gov.ph/ppp_projects/50-year-integrated-development-plan-for-mactan-cebu-international-airport-mcia-project/", "https://ppp.gov.ph/ppp_projects/san-pablo-city-water-district-septage-management-program/", "https://ppp.gov.ph/ppp_projects/skyway-stage-3/", "https://ppp.gov.ph/ppp_projects/clark-international-airport-project-engineering-procurement-and-construction/", "https://ppp.gov.ph/ppp_projects/butuan-city-water-district-jva-for-water-supply-development-and-water-treatment/", "https://ppp.gov.ph/ppp_projects/rehabilitation-and-operation-of-the-cabanatuan-city-slaughterhouse-project/"] 

z = []
#y = {}
f = []
for i in u:
    r = requests.get(i)
    t = r.text
    s = BeautifulSoup(t)
    a = "body > div:nth-child(7) > div.large-9.medium-8.columns.center > div.su-accordion > div > div > div.su-spoiler-content.su-clearfix"
    v = s.select(a)[0]
    
    y = {}
    
    x = v.find_all("p")
    try:
        if x[6].text.strip().lower().find("php") == 0 or x[6].text.strip().lower().find("usd") == 0 or x[6].text.strip().lower().find("million") > 0 or x[6].text.strip().lower().find("billion") > 0 or x[6].text.strip().lower().find("milion") > 0 or x[6].text.strip().lower().find("bilion") > 0 or x[6].text.strip().lower().find("-") == 0 or x[6].text.strip().lower().find("tbd") == 0 or x[6].text.strip().lower().find("for validation") == 0:
            p = x[6].text.strip()
        elif x[5].text.strip().lower().find("php") == 0 or x[5].text.strip().lower().find("usd") == 0 or x[5].text.strip().lower().find("million") > 0 or x[5].text.strip().lower().find("billion") > 0 or x[5].text.strip().lower().find("milion") > 0 or x[5].text.strip().lower().find("bilion") > 0 or x[5].text.strip().lower().find("-") == 0 or x[5].text.strip().lower().find("tbd") == 0 or x[5].text.strip().lower().find("for") == 0:
            p = x[5].text.strip()
        elif x[4].text.strip().lower().find("php") == 0 or x[4].text.strip().lower().find("usd") == 0 or x[4].text.strip().lower().find("million") > 0 or x[4].text.strip().lower().find("billion") > 0 or x[4].text.strip().lower().find("milion") > 0 or x[4].text.strip().lower().find("bilion") > 0 or x[4].text.strip().lower().find("-") == 0 or x[4].text.strip().lower().find("tbd") == 0 or x[4].text.strip().lower().find("for") == 0:
            p = x[4].text.strip()
        elif x[3].text.strip().lower().find("php") == 0 or x[3].text.strip().lower().find("usd") == 0 or x[3].text.strip().lower().find("million") > 0 or x[3].text.strip().lower().find("billion") > 0 or x[3].text.strip().lower().find("milion") > 0 or x[3].text.strip().lower().find("bilion") > 0 or x[3].text.strip().lower().find("-") == 0 or x[3].text.strip().lower().find("tbd") == 0 or x[3].text.strip().lower().find("for") == 0:
            p = x[3].text.strip()
        elif x[7].text.strip().lower().find("php") == 0 or x[7].text.strip().lower().find("usd") == 0 or x[7].text.strip().lower().find("million") > 0 or x[7].text.strip().lower().find("billion") > 0 or x[7].text.strip().lower().find("milion") > 0 or x[7].text.strip().lower().find("bilion") > 0 or x[7].text.strip().lower().find("-") == 0 or x[7].text.strip().lower().find("tbd") == 0 or x[7].text.strip().lower().find("for") == 0:
            p = x[7].text.strip()
        elif x[10].text.strip().lower().find("php") == 0 or x[10].text.strip().lower().find("usd") == 0 or x[10].text.strip().lower().find("million") > 0 or x[10].text.strip().lower().find("billion") > 0 or x[10].text.strip().lower().find("milion") > 0 or x[10].text.strip().lower().find("bilion") > 0 or x[10].text.strip().lower().find("-") == 0 or x[10].text.strip().lower().find("tbd") == 0 or x[10].text.strip().lower().find("for") == 0:
            p = x[10].text.strip()
        elif x[11].text.strip().lower().find("php") == 0 or x[11].text.strip().lower().find("usd") == 0 or x[11].text.strip().lower().find("million") > 0 or x[11].text.strip().lower().find("billion") > 0 or x[11].text.strip().lower().find("milion") > 0 or x[11].text.strip().lower().find("bilion") > 0 or x[11].text.strip().lower().find("-") == 0 or x[11].text.strip().lower().find("tbd") == 0 or x[11].text.strip().lower().find("for") == 0:
            p = x[11].text.strip()
    except:
        p = "Not Indicated"
    y["Cost"] = p
    y["URL"] = i
    
    z.append(y)

    #o = [{v: q} for v, q in y.items()]
    #f.append(o)
    #print(o)

with open("test_data.json", "w") as test:
    json.dump(z, test)

# %%
for j in table_rows:
    rows = j.find("a")
    ref = rows.get("href")
    
    new_resp = requests.get(ref)
    c_text = new_resp.text
    c_soup = BeautifulSoup(c_text)
    b_selector = "body > div:nth-child(7) > div.large-9.medium-8.columns.center > div.su-accordion > div > div > div.su-spoiler-content.su-clearfix"
    view_body = c_soup.select(b_selector)[0]

    c = view_body.find_all("p")
    
    try:
        cost = c[3].text.strip()
        cost_two = c[4].text.strip()
        cost_three = c[5].text.strip()
        cost_four = c[6].text.strip()
        #cost_five = c[7].text.strip()
        #cost_six = c[8].text.strip()
        cost_seven = c[2].text.strip()
        #cost_eight = c[9].text.strip()

        if cost.lower().find("php") == 0 or cost.lower().find("usd") == 0 or cost.lower().find("million") > 0 or cost.lower().find("billion") > 0 or cost.lower().find("milion") > 0 or cost.lower().find("bilion") > 0 or cost.lower().find("-") == 0 or cost.lower().find("tbd") == 0 or cost.lower().find("for") == 0:
            project_cost = cost 
        elif cost_two.lower().find("php") == 0 or cost_two.lower().find("usd") == 0 or cost_two.lower().find("tbd") == 0 or cost_two.find("-") == 0 or cost_two.lower().find("million") > 0 or cost_two.lower().find("milion") > 0 or cost_two.lower().find("billion") > 0 or cost_two.lower().find("bilion") > 0 or cost_two.lower().find("for") == 0:
            project_cost = cost_two 
        elif cost_three.lower().find("php") == 0 or cost_three.lower().find("usd") == 0 or cost_three.lower().find("tbd") == 0 or cost_three.find("-") == 0 or cost_three.lower().find("million") > 0 or cost_three.lower().find("milion") > 0 or cost_three.lower().find("billion") > 0 or cost_three.lower().find("bilion") > 0 or cost_three.lower().find("for") == 0:
            project_cost = cost_three 
        elif cost_four.lower().find("php") == 0 or cost_four.lower().find("usd") == 0 or cost_four.lower().find("tbd") == 0 or cost_four.find("-") == 0 or cost_four.lower().find("million") > 0 or cost_four.lower().find("milion") > 0 or cost_four.lower().find("billion") > 0 or cost_four.lower().find("bilion") > 0 or cost_four.lower().find("for") == 0:
            project_cost = cost_four 
        elif cost_five.lower().find("php") == 0 or cost_five.lower().find("usd") == 0 or cost_five.lower().find("tbd") == 0 or cost_five.find("-") == 0 or cost_five.lower().find("million") > 0 or cost_five.lower().find("milion") > 0 or cost_five.lower().find("billion") > 0 or cost_five.lower().find("bilion") > 0 or cost_five.lower().find("for") == 0:
            project_cost = cost_five 
        elif cost_six.lower().find("php") == 0 or cost_six.lower().find("usd") == 0 or cost_six.lower().find("tbd") == 0 or cost_six.find("-") == 0 or cost_six.lower().find("million") > 0 or cost_six.lower().find("milion") > 0 or cost_six.lower().find("billion") > 0 or cost_six.lower().find("bilion") > 0 or cost_six.lower().find("for") == 0:
            project_cost = cost_six 
        elif cost_seven.lower().find("php") == 0 or cost_seven.lower().find("usd") == 0 or cost_seven.lower().find("tbd") == 0 or cost_seven.find("-") == 0 or cost_seven.lower().find("million") > 0 or cost_seven.lower().find("milion") > 0 or cost_seven.lower().find("billion") > 0 or cost_seven.lower().find("bilion") > 0 or cost_seven.lower().find("for") == 0:
            project_cost = cost_seven 
        #elif cost_eight.lower().find("php") == 0 or cost_eight.lower().find("usd") == 0 or cost_eight.lower().find("tbd") == 0 or cost_eight.find("-") == 0 or cost_eight.lower().find("million") > 0 or cost_eight.lower().find("milion") > 0 or cost_eight.lower().find("billion") > 0 or cost_eight.lower().find("bilion") > 0 or cost_eight.lower().find("for") == 0:
         #   project_cost = cost_eight
       
        #print(project_cost)
        
    except:
        pass
        #print("Error", ref)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-151-55c1e5027731> in <module>
#       3     ref = rows.get("href")
#       4
# ----> 5     new_resp = requests.get(ref)
#       6     c_text = new_resp.text
#       7     c_soup = BeautifulSoup(c_text)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ...

# %%
# use re to make it shorter?

for j in table_rows: 
    rows = j.find("a")
    ref = rows.get("href")
    
    new_resp = requests.get(ref)
    c_text = new_resp.text
    c_soup = BeautifulSoup(c_text)
    b_selector = "body > div:nth-child(7) > div.large-9.medium-8.columns.center > div.su-accordion > div > div > div.su-spoiler-content.su-clearfix"
    view_body = c_soup.select(b_selector)[0]

    c = view_body.find_all("p")
    
    try:
        if c[6].text.strip().lower().find("php") == 0 or c[6].text.strip().lower().find("usd") == 0 or c[6].text.strip().lower().find("tbd") == 0 or c[6].text.strip().find("-") == 0 or c[6].text.strip().lower().find("million") > 0 or c[6].text.strip().lower().find("milion") > 0 or c[6].text.strip().lower().find("billion") > 0 or c[6].text.strip().lower().find("bilion") > 0 or c[6].text.strip().lower().find("for validation") == 0:
            project_cost = c[6].text.strip() 
        elif c[3].text.strip().lower().find("php") == 0 or c[3].text.strip().lower().find("usd") == 0 or c[3].text.strip().lower().find("million") > 0 or c[3].text.strip().lower().find("billion") > 0 or c[3].text.strip().lower().find("milion") > 0 or c[3].text.strip().lower().find("bilion") > 0 or c[3].text.strip().lower().find("-") == 0 or c[3].text.strip().lower().find("tbd") == 0 or c[3].text.strip().lower().find("for validation") == 0:
            project_cost = c[3].text.strip() 
        elif c[4].text.strip().lower().find("php") == 0 or c[4].text.strip().lower().find("usd") == 0 or c[4].text.strip().lower().find("tbd") == 0 or c[4].text.strip().find("-") == 0 or c[4].text.strip().lower().find("million") > 0 or c[4].text.strip().lower().find("milion") > 0 or c[4].text.strip().lower().find("billion") > 0 or c[4].text.strip().lower().find("bilion") > 0 or c[4].text.strip().lower().find("for validation") == 0:
            project_cost = c[4].text.strip() 
        elif c[5].text.strip().lower().find("php") == 0 or c[5].text.strip().lower().find("usd") == 0 or c[5].text.strip().lower().find("tbd") == 0 or c[5].text.strip().find("-") == 0 or c[5].text.strip().lower().find("million") > 0 or c[5].text.strip().lower().find("milion") > 0 or c[5].text.strip().lower().find("billion") > 0 or c[5].text.strip().lower().find("bilion") > 0 or c[5].text.strip().lower().find("for validation") == 0:
            project_cost = c[5].text.strip() 
        elif c[7].text.strip().lower().find("php") == 0 or c[7].text.strip().lower().find("usd") == 0 or c[7].text.strip().lower().find("tbd") == 0 or c[7].text.strip().find("-") == 0 or c[7].text.strip().lower().find("million") > 0 or c[7].text.strip().lower().find("milion") > 0 or c[7].text.strip().lower().find("billion") > 0 or c[7].text.strip().lower().find("bilion") > 0 or c[7].text.strip().lower().find("for validation") == 0:
            project_cost = c[7].text.strip() 
        elif c[8].text.strip().lower().find("php") == 0 or c[8].text.strip().lower().find("usd") == 0 or c[8].text.strip().lower().find("tbd") == 0 or c[8].text.strip().find("-") == 0 or c[8].text.strip().lower().find("million") > 0 or c[8].text.strip().lower().find("milion") > 0 or c[8].text.strip().lower().find("billion") > 0 or c[8].text.strip().lower().find("bilion") > 0 or c[8].text.strip().lower().find("for validation") == 0:
            project_cost = c[8].text.strip() 
        elif c[2].text.strip().lower().find("php") == 0 or c[2].text.strip().lower().find("usd") == 0 or c[2].text.strip().lower().find("tbd") == 0 or c[2].text.strip().find("-") == 0 or c[2].text.strip().lower().find("million") > 0 or c[2].text.strip().lower().find("milion") > 0 or c[2].text.strip().lower().find("billion") > 0 or c[2].text.strip().lower().find("bilion") > 0 or c[2].text.strip().lower().find("for validation") == 0:
            project_cost = c[2].text.strip() 
        elif c[9].text.strip().lower().find("php") == 0 or c[9].text.strip().lower().find("usd") == 0 or c[9].text.strip().lower().find("tbd") == 0 or c[9].text.strip().find("-") == 0 or c[9].text.strip().lower().find("million") > 0 or c[9].text.strip().lower().find("milion") > 0 or c[9].text.strip().lower().find("billion") > 0 or c[9].text.strip().lower().find("bilion") > 0 or c[9].text.strip().lower().find("for validation") == 0:
            project_cost = c[9].text.strip()
        elif c[10].text.strip().lower().find("php") == 0 or c[10].text.strip().lower().find("usd") == 0 or c[10].text.strip().lower().find("tbd") == 0 or c[10].text.strip().find("-") == 0 or c[10].text.strip().lower().find("million") > 0 or c[10].text.strip().lower().find("milion") > 0 or c[10].text.strip().lower().find("billion") > 0 or c[10].text.strip().lower().find("bilion") > 0 or c[10].text.strip().lower().find("for validation") == 0:
            project_cost = c[10].text.strip()
        elif c[11].text.strip().lower().find("php") == 0 or c[11].text.strip().lower().find("usd") == 0 or c[11].text.strip().lower().find("tbd") == 0 or c[11].text.strip().find("-") == 0 or c[11].text.strip().lower().find("million") > 0 or c[11].text.strip().lower().find("milion") > 0 or c[11].text.strip().lower().find("billion") > 0 or c[11].text.strip().lower().find("bilion") > 0 or c[11].text.strip().lower().find("for validation") == 0:
            project_cost = c[11].text.strip()
        
        print(project_cost)
        
    except:
        print("Not Indicated") #178/177 -> shudve said not indicated
# Out:
# Php 1,604.59 Million
# Php 7,604.90 Million
# Php 5,229.90 Million
# TBD
# TBD
# Php 110,817,774.31
# -
# Php 6.128 Billion
# Php 5.5 Billion
# -
# Php 9.138 Billion
# Php 0.0495 Billion
# Php 17.4 Billion
# Php 3.22 Billion
# Php 2.66 Billion
# Php 5.2 Billion
# Php 551 Million
# Php 2.180 Billion
# Php 240 Million
# Php 2,140.63
# Php 3,153.69 Million
# Php 1,598.07
# -
# Php 1,124.41 Million
# -
# Php 2,955.97 Million
# Php 2,164.00 Million
# Php 1,457.00 Million
# Php 1,031.17 Million
# Php 1,624.23 Million
# Php 2,661.13 Million
# Php 3,711.22
# Php 2,918.46 Million
# -
# Php 570.26 Million
# Php 2,343.34 Million
# Php 6,143.74 Million
# Php 1,787.14 Million
# Php 3,343 Million
# Php 1,554.74 Million
# Php 1,366.88 Million
# Php 1,902.69 Million
# -
# Php 2.9863 Billion
# Php 642.37 Million
# -
# -
# Php 2.80 Billion
# Php 12.350 Billion
# -
# Php 308.60 Million
# Php 4.00 Billion
# Php 26.020 Billion
# -
# Php 48.54 Million
# Php 35.5 Billion
# Php 757.61 Million
# -
# -
# -
# ...

# %%
# FINAL

import requests
from bs4 import BeautifulSoup
import json

webscraped_data = []

url = "https://ppp.gov.ph/project-database/"
response = requests.get(url)
page_text = response.text
soup = BeautifulSoup(page_text)
selector = "body > div:nth-child(7) > div.large-9.medium-8.columns.center > div.large-6.columns.map-result > table"
view_content_element = soup.select(selector)[0]
new_selector = "tbody > tr"
table_rows = view_content_element.select(new_selector)


for tr in table_rows:
    
    # MAIN PAGE
    cols = tr.find_all('td')
    title_selector = cols[0]
    title = title_selector.text
    region_selector = cols[1]
    region = region_selector.text
    sector_selector = cols[2]
    sector = sector_selector.text
    status_selector = cols[3]
    status = status_selector.text.split(",")[0]
    try:
        award = status_selector.text.split(",")[1]
    except:
        award = None
    agent_selector = cols[4]
    agent = agent_selector.text
    
    page_data = {}
    
    page_data["Project Title"] = title
    page_data["Region"] = region
    page_data["Sector"] = sector
    page_data["Status"] = status
    page_data["Award"] = award
    page_data["Implementing Agency"] = agent
    
    # EACH SITE -> get cost
    rows = tr.find("a")
    ref = rows.get("href")
    
    new_resp = requests.get(ref)
    c_text = new_resp.text
    c_soup = BeautifulSoup(c_text)
    b_selector = "body > div:nth-child(7) > div.large-9.medium-8.columns.center > div.su-accordion > div > div > div.su-spoiler-content.su-clearfix"
    view_body = c_soup.select(b_selector)[0]

    c = view_body.find_all("p")
    
    try:
        
        if c[6].text.strip().lower().find("php") == 0 or c[6].text.strip().lower().find("usd") == 0 or c[6].text.strip().lower().find("tbd") == 0 or c[6].text.strip().find("-") == 0 or c[6].text.strip().lower().find("million") > 0 or c[6].text.strip().lower().find("milion") > 0 or c[6].text.strip().lower().find("billion") > 0 or c[6].text.strip().lower().find("bilion") > 0 or c[6].text.strip().lower().find("for validation") == 0:
            project_cost = c[6].text.strip() 
        elif c[3].text.strip().lower().find("php") == 0 or c[3].text.strip().lower().find("usd") == 0 or c[3].text.strip().lower().find("million") > 0 or c[3].text.strip().lower().find("billion") > 0 or c[3].text.strip().lower().find("milion") > 0 or c[3].text.strip().lower().find("bilion") > 0 or c[3].text.strip().lower().find("-") == 0 or c[3].text.strip().lower().find("tbd") == 0 or c[3].text.strip().lower().find("for validation") == 0:
            project_cost = c[3].text.strip() 
        elif c[4].text.strip().lower().find("php") == 0 or c[4].text.strip().lower().find("usd") == 0 or c[4].text.strip().lower().find("tbd") == 0 or c[4].text.strip().find("-") == 0 or c[4].text.strip().lower().find("million") > 0 or c[4].text.strip().lower().find("milion") > 0 or c[4].text.strip().lower().find("billion") > 0 or c[4].text.strip().lower().find("bilion") > 0 or c[4].text.strip().lower().find("for validation") == 0:
            project_cost = c[4].text.strip() 
        elif c[5].text.strip().lower().find("php") == 0 or c[5].text.strip().lower().find("usd") == 0 or c[5].text.strip().lower().find("tbd") == 0 or c[5].text.strip().find("-") == 0 or c[5].text.strip().lower().find("million") > 0 or c[5].text.strip().lower().find("milion") > 0 or c[5].text.strip().lower().find("billion") > 0 or c[5].text.strip().lower().find("bilion") > 0 or c[5].text.strip().lower().find("for validation") == 0:
            project_cost = c[5].text.strip() 
        elif c[7].text.strip().lower().find("php") == 0 or c[7].text.strip().lower().find("usd") == 0 or c[7].text.strip().lower().find("tbd") == 0 or c[7].text.strip().find("-") == 0 or c[7].text.strip().lower().find("million") > 0 or c[7].text.strip().lower().find("milion") > 0 or c[7].text.strip().lower().find("billion") > 0 or c[7].text.strip().lower().find("bilion") > 0 or c[7].text.strip().lower().find("for validation") == 0:
            project_cost = c[7].text.strip() 
        elif c[8].text.strip().lower().find("php") == 0 or c[8].text.strip().lower().find("usd") == 0 or c[8].text.strip().lower().find("tbd") == 0 or c[8].text.strip().find("-") == 0 or c[8].text.strip().lower().find("million") > 0 or c[8].text.strip().lower().find("milion") > 0 or c[8].text.strip().lower().find("billion") > 0 or c[8].text.strip().lower().find("bilion") > 0 or c[8].text.strip().lower().find("for validation") == 0:
            project_cost = c[8].text.strip() 
        elif c[2].text.strip().lower().find("php") == 0 or c[2].text.strip().lower().find("usd") == 0 or c[2].text.strip().lower().find("tbd") == 0 or c[2].text.strip().find("-") == 0 or c[2].text.strip().lower().find("million") > 0 or c[2].text.strip().lower().find("milion") > 0 or c[2].text.strip().lower().find("billion") > 0 or c[2].text.strip().lower().find("bilion") > 0 or c[2].text.strip().lower().find("for validation") == 0:
            project_cost = c[2].text.strip() 
        elif c[9].text.strip().lower().find("php") == 0 or c[9].text.strip().lower().find("usd") == 0 or c[9].text.strip().lower().find("tbd") == 0 or c[9].text.strip().find("-") == 0 or c[9].text.strip().lower().find("million") > 0 or c[9].text.strip().lower().find("milion") > 0 or c[9].text.strip().lower().find("billion") > 0 or c[9].text.strip().lower().find("bilion") > 0 or c[9].text.strip().lower().find("for validation") == 0:
            project_cost = c[9].text.strip()
        elif c[10].text.strip().lower().find("php") == 0 or c[10].text.strip().lower().find("usd") == 0 or c[10].text.strip().lower().find("tbd") == 0 or c[10].text.strip().find("-") == 0 or c[10].text.strip().lower().find("million") > 0 or c[10].text.strip().lower().find("milion") > 0 or c[10].text.strip().lower().find("billion") > 0 or c[10].text.strip().lower().find("bilion") > 0 or c[10].text.strip().lower().find("for validation") == 0:
            project_cost = c[10].text.strip()
        elif c[11].text.strip().lower().find("php") == 0 or c[11].text.strip().lower().find("usd") == 0 or c[11].text.strip().lower().find("tbd") == 0 or c[11].text.strip().find("-") == 0 or c[11].text.strip().lower().find("million") > 0 or c[11].text.strip().lower().find("milion") > 0 or c[11].text.strip().lower().find("billion") > 0 or c[11].text.strip().lower().find("bilion") > 0 or c[11].text.strip().lower().find("for validation") == 0:
            project_cost = c[11].text.strip()
        
    except:
        project_cost = "Not Indicated" #177 -> shudve said not indicated
    
    page_data["Cost"] = project_cost
    
    webscraped_data.append(page_data)
    
webscraped_data[7]["Award"] = webscraped_data[7]["Status"] # switched value cos no status indicated in the og site
webscraped_data[7]["Status"] = "Unknown"

print(webscraped_data)    

with open("complete_data.json", "w") as complete: 
    json.dump(webscraped_data, complete)
# Out:
# [{'Project Title': 'PPP for School Infrastructure Project Phase II (PSIP II) – Package E', 'Region': 'REGION X - NORTHERN MINDANAO,CARAGA', 'Sector': 'Education', 'Status': 'Under Construction', 'Award': 'Awarded', 'Implementing Agency': 'Department of Education (DepEd)', 'Cost': 'Php 1,604.59 Million'}, {'Project Title': 'PPP for School Infrastructure Project Phase I (PSIP I) – Package C', 'Region': 'REGION IV-A - CALABARZON', 'Sector': 'Education', 'Status': 'Operational', 'Award': 'Awarded', 'Implementing Agency': 'Department of Education (DepEd)', 'Cost': 'Php 7,604.90 Million'}, {'Project Title': 'PPP for School Infrastructure Project Phase I (PSIP I) – Package B', 'Region': 'REGION III - CENTRAL LUZON', 'Sector': 'Education', 'Status': 'Operational', 'Award': 'Awarded', 'Implementing Agency': 'Department of Education (DepEd)', 'Cost': 'Php 5,229.90 Million'}, {'Project Title': 'Tri-City Ferry System Project', 'Region': 'REGION I - ILOCOS', 'Sector': 'Transportation,Ferry', 'Sta
# ...

# %%
webscraped_data[7]["Award"] = webscraped_data[7]["Status"] # clean nalang 
webscraped_data[7]["Status"] = "Unknown"

webscraped_data[7]
# Out:
# {'Project Title': 'Joint Venture Agreement for the Development and Disposition of a Portion of the North Triangle Property (Vertis North)',
#  'Region': 'NATIONAL CAPITAL REGION',
#  'Sector': 'Property Development',
#  'Status': 'Unknown',
#  'Award': 'Awarded',
#  'Implementing Agency': 'National Housing Authority',
#  'Cost': '-'}

# %%
# References

# https://stackoverflow.com/questions/3075550/how-can-i-get-href-links-from-html-using-python
